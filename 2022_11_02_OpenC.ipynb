# %%
# !pip install opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 MB 28.3 MB/s eta 0:00:0000:0100:01
# ...

# %%
cv2.version.opencv_version
# Out:
# '4.6.0.66'

# %%
imagefile = './lena.jpg'

# %%
img = cv2.imread(imagefile)
print(img.shape)
# Out:
# (512, 512, 3)

# %%
img
# Out:
# array([[[128, 138, 225],
#         [127, 137, 224],
#         [126, 136, 224],
#         ...,
#         [126, 145, 236],
#         [110, 129, 220],
#         [ 86, 104, 197]],
#
#        [[127, 137, 224],
#         [127, 137, 224],
#         [127, 137, 224],
#         ...,
#         [130, 150, 235],
#         [112, 132, 217],
#         [ 83, 102, 189]],
#
#        [[127, 137, 224],
#         [127, 137, 224],
#         [128, 138, 225],
#         ...,
#         [127, 148, 230],
#         [111, 133, 215],
#         [ 84, 105, 190]],
#
#        ...,
#
#        [[ 55,  21,  82],
#         [ 54,  20,  81],
#         [ 62,  28,  92],
#         ...,
#         [ 82,  71, 175],
#         [ 78,  68, 175],
#         [ 74,  65, 175]],
#
#        [[ 53,  19,  80],
#         [ 54,  20,  81],
#         [ 66,  32,  96],
#         ...,
#         [ 82,  69, 177],
#         [ 80,  71, 181],
#         [ 81,  72, 183]],
#
#        [[ 54,  20,  81],
#         [ 56,  22,  83],
#         [ 68,  34,  98],
# ...

# %%
img2 = cv2.imread(imagefile,0)
print(img2.shape)
# Out:
# (512, 512)

# %%
cv2.startWindowThread()
# Out:
# 0

# %%
cv2.imshow('Lena color', img)

# %%
cv2.imshow('Lena grayscale', img2)

# %%
cv2.waitKey()

# %%
cv2.destroyAllWindows()

# %%
cv2.imwrite('./Lena.bmp', img)
cv2.imwrite('./Lena.png', img)
cv2.imwrite('./Lena2.png', img2)
cv2.imwrite('./Lena2.jpg', img2)
# Out:
# True

# %%
import matplotlib.pyplot as plt
imagefile = './lena.jpg'
img_bgr = cv2.imread(imagefile) #blue green red
# plt.axis('off') 이게 없으면 축에 숫자가 표시됨

plt.imshow(img_bgr)
plt.show()

# %%
import matplotlib.pyplot as plt
imagefile = './lena.jpg'
img_bgr = cv2.imread(imagefile) #blue green red
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB) #색상 배열을 바꿔줌
plt.axis('off')

plt.imshow(img_rgb)
plt.show()

# %%
img_gray = cv2.imread(imagefile, cv2.IMREAD_GRAYSCALE)

plt.axis('off')
plt.imshow(img_gray, cmap='gray', interpolation='nearest')
plt.show()

# %%
img_gray = cv2.imread(imagefile, cv2.IMREAD_GRAYSCALE)

plt.axis('off')
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
img_gray = cv2.imread(imagefile, cv2.IMREAD_GRAYSCALE)

plt.axis('off')
plt.imshow(img_gray) #cmap='gray'를 빼니까 이렇게 나온다.
plt.show()

# %%
img_gray = cv2.imread(imagefile, cv2.IMREAD_GRAYSCALE)

plt.axis('off')
plt.imshow(img_gray, interpolation='nearest')
plt.show()

# %%
img_gray = cv2.imread(imagefile, cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=(4,4))
plt.subplots_adjust(left=0, right=0.5, bottom=0, top=0.5)

plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
img_gray = cv2.imread(imagefile, cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=(10,10))
plt.subplots_adjust(left=0, right=0.5, bottom=0, top=0.5)

plt.imshow(img_gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
fig = plt.figure(figsize=(4,4))

axarr = plt.subplots(4,1)

plt.subplot(1,2,1)
plt.imshow(lena1)
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(apple1)
plt.axis('off')

plt.subplot(2,2,1)
plt.imshow(baboon1)
plt.axis('off')

plt.subplot(2,2,2)
plt.imshow(orange1)
plt.axis('off')




plt.show()

# %%
lena = cv2.imread('./lena.jpg')
lena_rgb = cv2.cvtColor(lena, cv2.COLOR_BGR2RGB)
apple = cv2.imread('./apple.jpg')
apple_rgb = cv2.cvtColor(apple, cv2.COLOR_BGR2RGB)
baboon = cv2.imread('./baboon.jpg')
baboon_rgb = cv2.cvtColor(baboon, cv2.COLOR_BGR2RGB)
orange = cv2.imread('./orange.jpg')
orange_rgb = cv2.cvtColor(orange, cv2.COLOR_BGR2RGB)



fig = plt.figure(figsize=(6,6))

fig.add_subplot(2, 2, 1)
plt.imshow(lena_rgb)
plt.axis('off')
plt.title("lena")
fig.add_subplot(2, 2, 2)
plt.imshow(apple_rgb)
plt.axis('off')
plt.title("apple")
fig.add_subplot(2, 2, 3)
plt.imshow(baboon_rgb)
plt.axis('off')
plt.title("baboon")
fig.add_subplot(2, 2, 4)
plt.imshow(orange_rgb)
plt.axis('off')
plt.title("orange")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
lena = cv2.imread('./lena.jpg')
lena_rgb = cv2.cvtColor(lena, cv2.COLOR_BGR2RGB)
apple = cv2.imread('./apple.jpg')
apple_rgb = cv2.cvtColor(apple, cv2.COLOR_BGR2RGB)
baboon = cv2.imread('./baboon.jpg')
baboon_rgb = cv2.cvtColor(baboon, cv2.COLOR_BGR2RGB)
orange = cv2.imread('./orange.jpg')
orange_rgb = cv2.cvtColor(orange, cv2.COLOR_BGR2RGB)

fig = plt.figure(figsize=(5,5))

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.axis('off')
ax2.axis('off')
ax3.axis('off')
ax4.axis('off')

ax1.imshow(lena_rgb)
ax2.imshow(apple_rgb)
ax3.imshow(baboon_rgb)
ax4.imshow(orange_rgb)

ax1.title.set_text("lena")
ax2.title.set_text('apple')
ax3.title.set_text('baboon')
ax4.title.set_text('orange')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
#cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture('./vtest.avi')
frame_size = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
print('frame_size =', frame_size)
while True:
    retval, frame = cap.read()
    if not retval:
        break
    cv2.imshow('frame', frame)
    key = cv2.waitKey(25)
    if key == 27:
        break
if cap.isOpened():
    cap.release()
cv2.destroyAllWindows()
# Out:
#   File "/var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_3334/2985304452.py", line 1
#     cv2.imwrite(vtest, img[,params])
#                            ^
# SyntaxError: invalid syntax

# %%
lena_rgb.shape

# §비디오 획득 객체 생성
# •cv2.VideoCapture() → <VideoCatpure object>
# •cv2.VideoCapture(filename) → <VideoCatpure object>
# •cv2.VideoCapture(device) → <VideoCatpure object>
# •device = 0, 1, …
# §프레임 획득
# •cv2.VideoCapture.read([image]) → retval, image
# §프레임 잡기
# •cv2.VideoCapture.grab() → retval
# §프레임 획득
# •cv2.VideoCapture.retrieve([image[, channel]]) → retval, image

# %%
# §영상 입력
# •cv2.imread(filename[, flags]) → retval
# §영상 파일 출력
# •cv2.imwrite(filename, img[, params]) → retval
# §윈도우 생성
# •cv2.namedWindow(winname[, flags])
# §윈도우 표시
# •cv2.imshow(winname, mat)
# §키보드 입력대기
# •cv2.waitKey([,delay]) → retval
# §윈도우 파괴
# •cv2.destroyWindow(winname)
# •cv2.destroyAllWindows()

# %%
# §비디오 획득 객체 해제
# •cv2.VideoCapture.release()
# §비디오 특성 얻기
# •cv2.VideoCapture.get(propid) → retval
# §비디오 특성 설정
# •cv2.VideoCapture.set(propid, value) → retval
# §비디오 출력 객체 생성
# •cv2.VideoWriter([filename, fourcc, fps, frameSize[,isColor]]) → <VideoWriter object>
# §비디오 파일에 이미지 출력
# •cv2.VideoWriter.write(image)
# §비디오 출력 객체 해제
# cv2.VideoWriter.release()
# Out:
#   File "/var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_3334/1601823777.py", line 1
#     cv2.imread('./vtest.avi'[, flags])
#                              ^
# SyntaxError: invalid syntax

# %%
import numpy as np
img = np.zeros(shape=(512,512,3), dtype=np.uint8) +230
pt1=0,0
pt2=500,0
pt3=0,500
pt4=500,500
pt5=250, 0
pt6=250, 500
pt7=0, 250
pt8=500, 250
cv2.line(img,pt1, pt2, (255,0,0),5)
cv2.line(img,pt1, pt3, (0,0,255),5)
cv2.line(img, pt2, pt4, (0,255,0),5)
cv2.line(img, pt3, pt4, (100,100,100),5)
cv2.line(img,pt1, pt4, (255,0,255),5)
cv2.line(img,pt2, pt3, (0,255,255),5)
cv2.line(img,pt5, pt6, (200,100,100),5)
cv2.line(img,pt7, pt8, (100,100,200),5)

fig = plt.figure(figsize=(7,7))
plt.imshow(img)
plt.axis('off')

plt.show()

# %%
import numpy as np
img = np.zeros(shape=(512,512,3), dtype=np.uint8) +200
pt1=0,0
pt4=400,400

cv2.rectangle(img,pt1, pt4, (255,0,0),5)

fig = plt.figure(figsize=(7,7))
plt.imshow(img)
plt.axis('off')

plt.show()

# %%
img1 = np.zeros(shape=(512,512,3), dtype=np.uint8)+200
pt1=0,0
pt2=500,0
pt3=0,500
pt4=400,400
pt5 = 100,100
cv2.line(img1,pt1, pt2, (255,0,0),5)
cv2.line(img1,pt1, pt3, (0,0,255),10)
cv2.rectangle(img1,pt5, pt4, (0,255,0),-1)

fig=plt.figure(figsize=(6,6))
plt.imshow(img1)
plt.show()

# %%
img2 = np.zeros(shape=(512,512,3), dtype=np.uint8)+200
x1, x2 = 100, 400
y1, y2 = 100, 400
pt1 = 120, 50
pt2 = 300, 500

cv2.rectangle(img2, (x1,y1), (x2,y2),(0,0,255),5)

line = cv2.line(img2, pt1, pt2, (255,0,0),5)

rect = (x1, y1, x2-x1, y2-y1)

retval, rpt1, rpt2 = cv2.clipLine(rect, pt1, pt2)
print('retval :', retval)
print('rpt1 :', rpt1)
print('rpt2 :', rpt2)



fig=plt.figure(figsize=(6,6))
plt.imshow(img2)
plt.show()
# Out:
# retval : True
# rpt1 : (140, 100)
# rpt2 : (260, 399)

# %%
img3 = np.zeros(shape=(512,512,3), dtype=np.uint8)+200

pt = 256, 256
red = (255,0,0)

cv2.circle(img3, pt, 200, red, 1)
cv2.circle(img3, pt, 100, red, 1)
cv2.circle(img3, pt, 10, red, 1)
cv2.circle(img3, pt, 1, red, 1)

fig = plt.figure(figsize=(6,6))
plt.imshow(img3)
plt.show()

# %%
img4 = np.zeros(shape=(400,400,3), dtype=np.uint8)+100

blue = (0,0,255)

cx = img4.shape[0]//2
cy = img4.shape[1]//2

cv2.ellipse(img4, (cx,cy), (200, 100),-45, 0, 360, blue, 2)
fig = plt.figure(figsize=(6,6))
plt.imshow(img4)
plt.show()

# %%
img4 = np.zeros(shape=(400,400,3), dtype=np.uint8)+100

blue = (0,0,255)

cx = img4.shape[0]//2
cy = img4.shape[1]//2

cv2.ellipse(img4, (cx,cy), (200, 100),-45, 0, 360, blue, 2)
cv2.ellipse(img4, (cx,cy), (200, 100),45, 0, 360, (255,0,0), 2)
cv2.ellipse(img4, (cx,cy), (200, 100),90, 0, 360, (0,255,0), 2)
cv2.ellipse(img4, (cx,cy), (200, 100),0, 0, 360, (255,0,255), 2)

fig = plt.figure(figsize=(6,6))
plt.imshow(img4)
plt.show()

# %%
img4 = np.zeros(shape=(400,400,3), dtype=np.uint8)+100

blue = (0,0,255)

cx = img4.shape[0]//2
cy = img4.shape[1]//2

cv2.ellipse(img4, (cx,cy), (200, 100),-45, 135, 360, (255,255,0), 2)
cv2.ellipse(img4, (cx,cy), (200, 100),45, 135, 360, (255,0,0), 2)
cv2.ellipse(img4, (cx,cy), (200, 100),90, 135, 360, (0,255,0), 2)
cv2.ellipse(img4, (cx,cy), (200, 100),0, 135, 360, (255,0,255), 2)

fig = plt.figure(figsize=(6,6))
plt.imshow(img4)
plt.show()

# %%
img4 = np.zeros(shape=(400,400,3), dtype=np.uint8)+100

blue = (0,0,255)
pt1 = 120, 50
pt2 = 300, 500

cx = img4.shape[0]//2
cy = img4.shape[1]//2
box = cv2.rectangle(img4, pt1, pt2, (255,0,0), 1)
cv2.ellipse(img4, box, 45,0,360,blue, 2)
# cv2.ellipse(img4, (cx,cy), (200, 100),45, 0, 360, (255,0,0), 2)
# cv2.ellipse(img4, (cx,cy), (200, 100),90, 0, 360, (0,255,0), 2)
# cv2.ellipse(img4, (cx,cy), (200, 100),0, 0, 360, (255,0,255), 2)

fig = plt.figure(figsize=(6,6))
plt.imshow(img4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_3334/160694770.py in <module>
#       8 cy = img4.shape[1]//2
#       9 box = cv2.rectangle(img4, pt1, pt2, (255,0,0), 1)
# ---> 10 cv2.ellipse(img4, (cx,cy),box, 45,0,360,blue, 2)
#      11 # cv2.ellipse(img4, (cx,cy), (200, 100),45, 0, 360, (255,0,0), 2)
#      12 # cv2.ellipse(img4, (cx,cy), (200, 100),90, 0, 360, (0,255,0), 2)
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'ellipse'
# > Overload resolution failed:
# >  - Can't parse 'axes'. Expected sequence length 2, got 400
# >  - Can't parse 'axes'. Expected sequence length 2, got 400
# >  - ellipse() takes at most 5 arguments (8 given)
# >  - ellipse() takes at most 5 arguments (8 given)
