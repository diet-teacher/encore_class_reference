# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json

# %%
df = sns.load_dataset('titanic').loc[:, 'survived':'age'] # 타이타닉 1~5행까지 df에 저장

# %%
df
# Out:
#      survived  pclass     sex   age
# 0           0       3    male  22.0
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 4           0       3    male  35.0
# ..        ...     ...     ...   ...
# 886         0       2    male  27.0
# 887         1       1  female  19.0
# 888         0       3  female   NaN
# 889         1       1    male  26.0
# 890         0       3    male  32.0
#
# [891 rows x 4 columns]

# %%
ls = list(df.columns) # 열 이름 리스트 만들기

# %%
ls.sort()

# %%
df[ls]
# Out:
#       age  pclass     sex  survived
# 0    22.0       3    male         0
# 1    38.0       1  female         1
# 2    26.0       3  female         1
# 3    35.0       1  female         1
# 4    35.0       3    male         0
# ..    ...     ...     ...       ...
# 886  27.0       2    male         0
# 887  19.0       1  female         1
# 888   NaN       3  female         0
# 889  26.0       1    male         1
# 890  32.0       3    male         0
#
# [891 rows x 4 columns]

# %%
ls = list(df.columns)

# %%
np.random.shuffle(ls)

# %%
df[ls]
# Out:
#         sex  pclass   age  survived
# 0      male       3  22.0         0
# 1    female       1  38.0         1
# 2    female       3  26.0         1
# 3    female       1  35.0         1
# 4      male       3  35.0         0
# ..      ...     ...   ...       ...
# 886    male       2  27.0         0
# 887  female       1  19.0         1
# 888  female       3   NaN         0
# 889    male       1  26.0         1
# 890    male       3  32.0         0
#
# [891 rows x 4 columns]

# %%
ls.sort(reverse=True)

# %%
df[ls]
# Out:
#      survived     sex  pclass   age
# 0           0    male       3  22.0
# 1           1  female       1  38.0
# 2           1  female       3  26.0
# 3           1  female       1  35.0
# 4           0    male       3  35.0
# ..        ...     ...     ...   ...
# 886         0    male       2  27.0
# 887         1  female       1  19.0
# 888         0  female       3   NaN
# 889         1    male       1  26.0
# 890         0    male       3  32.0
#
# [891 rows x 4 columns]

# %%
ls.sort_values() # 열 이름 알파벳 순으로 정렬하기
# Out:
# Index(['adult_male', 'age', 'alive', 'alone', 'class', 'deck', 'embark_town',
#        'embarked', 'fare', 'parch', 'pclass', 'sex', 'sibsp', 'survived',
#        'who'],
#       dtype='object')

# %%
df[ls.sort_values()] # 데이터프레임[열이름리스트] 방식으로 열 순서 변경해 보기
# Out:
#    adult_male   age alive  alone  class deck  embark_town embarked     fare  \
# 0        True  22.0    no  False  Third  NaN  Southampton        S   7.2500
# 1       False  38.0   yes  False  First    C    Cherbourg        C  71.2833
# 2       False  26.0   yes   True  Third  NaN  Southampton        S   7.9250
# 3       False  35.0   yes  False  First    C  Southampton        S  53.1000
# 4        True  35.0    no   True  Third  NaN  Southampton        S   8.0500
#
#    parch  pclass     sex  sibsp  survived    who
# 0      0       3    male      1         0    man
# 1      0       1  female      1         1  woman
# 2      0       3  female      0         1  woman
# 3      0       1  female      1         1  woman
# 4      0       3    male      0         0    man

# %%
df[['adult_male', 'age', 'alive', 'alone', 'class', 'deck', 'embark_town',
       'embarked', 'fare', 'parch', 'pclass', 'sex', 'sibsp', 'survived',
       'who']]  # 데이터프레임[열이름리스트] 방식으로 열 순서 변경해 보기
# Out:
#    adult_male   age alive  alone  class deck  embark_town embarked     fare  \
# 0        True  22.0    no  False  Third  NaN  Southampton        S   7.2500
# 1       False  38.0   yes  False  First    C    Cherbourg        C  71.2833
# 2       False  26.0   yes   True  Third  NaN  Southampton        S   7.9250
# 3       False  35.0   yes  False  First    C  Southampton        S  53.1000
# 4        True  35.0    no   True  Third  NaN  Southampton        S   8.0500
#
#    parch  pclass     sex  sibsp  survived    who
# 0      0       3    male      1         0    man
# 1      0       1  female      1         1  woman
# 2      0       3  female      0         1  woman
# 3      0       1  female      1         1  woman
# 4      0       3    male      0         0    man

# %%
ls.sort_values(ascending=False)
# Out:
# Index(['who', 'survived', 'sibsp', 'sex', 'pclass', 'parch', 'fare',
#        'embarked', 'embark_town', 'deck', 'class', 'alone', 'alive', 'age',
#        'adult_male'],
#       dtype='object')

# %%
df[['who', 'survived', 'sibsp', 'sex', 'pclass', 'parch', 'fare',
       'embarked', 'embark_town', 'deck', 'class', 'alone', 'alive', 'age',
       'adult_male']]
# Out:
#      who  survived  sibsp     sex  pclass  parch     fare embarked  \
# 0    man         0      1    male       3      0   7.2500        S
# 1  woman         1      1  female       1      0  71.2833        C
# 2  woman         1      0  female       3      0   7.9250        S
# 3  woman         1      1  female       1      0  53.1000        S
# 4    man         0      0    male       3      0   8.0500        S
#
#    embark_town deck  class  alone alive   age  adult_male
# 0  Southampton  NaN  Third  False    no  22.0        True
# 1    Cherbourg    C  First  False   yes  38.0       False
# 2  Southampton  NaN  Third   True   yes  26.0       False
# 3  Southampton    C  First  False   yes  35.0       False
# 4  Southampton  NaN  Third   True    no  35.0        True

# %%
df[ls.sort_values(ascending=False)] # 열 이름 역순ㅇ로 정렬하고 열 순서 변경해보기
# Out:
#      who  survived  sibsp     sex  pclass  parch     fare embarked  \
# 0    man         0      1    male       3      0   7.2500        S
# 1  woman         1      1  female       1      0  71.2833        C
# 2  woman         1      0  female       3      0   7.9250        S
# 3  woman         1      1  female       1      0  53.1000        S
# 4    man         0      0    male       3      0   8.0500        S
#
#    embark_town deck  class  alone alive   age  adult_male
# 0  Southampton  NaN  Third  False    no  22.0        True
# 1    Cherbourg    C  First  False   yes  38.0       False
# 2  Southampton  NaN  Third   True   yes  26.0       False
# 3  Southampton    C  First  False   yes  35.0       False
# 4  Southampton  NaN  Third   True    no  35.0        True

# %%
df[['pclass', 'sex', 'age', 'survived']]
# Out:
#    pclass     sex   age  survived
# 0       3    male  22.0         0
# 1       1  female  38.0         1
# 2       3  female  26.0         1
# 3       1  female  35.0         1
# 4       3    male  35.0         0

# %%
df = pd.read_excel('./주가데이터.xlsx').head(5)

# %%
df
# Out:
#          연월일   당일종가  전일종가     시가     고가     저가     거래량
# 0 2018-07-02  10100   600  10850  10900  10000  137977
# 1 2018-06-29  10700   300  10550  10900   9990  170253
# 2 2018-06-28  10400   500  10900  10950  10150  155769
# 3 2018-06-27  10900   100  10800  11050  10500  133548
# 4 2018-06-26  10800   350  10900  11000  10700   63039

# %%
df.dtypes
# Out:
# 연월일     datetime64[ns]
# 당일종가             int64
# 전일종가             int64
# 시가               int64
# 고가               int64
# 저가               int64
# 거래량              int64
# dtype: object

# %%
df.연월일.dtypes
# Out:
# dtype('<M8[ns]')

# %%
df.당일종가.dtype
# Out:
# dtype('int64')

# %%
df.전일종가.dtype
# Out:
# dtype('int64')

# %%
df.시가.dtypes
# Out:
# dtype('int64')

# %%
df.고가.dtype
# Out:
# dtype('int64')

# %%
df.연월일 = df.연월일.astype('str')

# %%
type(df.연월일.astype('str')[0])
# Out:
# str

# %%
df.연월일.dtypes
# Out:
# dtype('O')

# %%
dates = df.연월일.str.split('-')

# %%
dates
# Out:
# 0    [2018, 07, 02]
# 1    [2018, 07, 02]
# 2    [2018, 07, 02]
# 3    [2018, 07, 02]
# 4    [2018, 07, 02]
# Name: 연월일, dtype: object

# %%
df['y'] = dates.str.get(0)

# %%
df['m'] = dates.str.get(1)

# %%
df['d'] = dates.str.get(2)

# %%
dates
# Out:
# 0    [0   2018, 07, 02\n1   2018, 06, 29\n2   2018,...
# 1    [0   2018, 07, 02\n1   2018, 06, 29\n2   2018,...
# 2    [0   2018, 07, 02\n1   2018, 06, 29\n2   2018,...
# 3    [0   2018, 07, 02\n1   2018, 06, 29\n2   2018,...
# 4    [0   2018, 07, 02\n1   2018, 06, 29\n2   2018,...
# Name: 연월일, dtype: object

# %%
df
# Out:
#           연월일   당일종가  전일종가     시가     고가     저가     거래량     y   d   m
# 0  2018-07-02  10100   600  10850  10900  10000  137977  2018  02  07
# 1  2018-07-02  10700   300  10550  10900   9990  170253  2018  02  07
# 2  2018-07-02  10400   500  10900  10950  10150  155769  2018  02  07
# 3  2018-07-02  10900   100  10800  11050  10500  133548  2018  02  07
# 4  2018-07-02  10800   350  10900  11000  10700   63039  2018  02  07

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic['age'] < 10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
titanic[titanic['age'] < 10] # 나이가 10세 미만인 사람만 출력
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male  2.00      3      1  21.0750        S   Third
# 10          1       3  female  4.00      1      1  16.7000        S   Third
# 16          0       3    male  2.00      4      1  29.1250        Q   Third
# 24          0       3  female  8.00      3      1  21.0750        S   Third
# 43          1       2  female  3.00      1      2  41.5792        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 827         1       2    male  1.00      0      2  37.0042        C  Second
# 831         1       2    male  0.83      1      1  18.7500        S  Second
# 850         0       3    male  4.00      4      2  31.2750        S   Third
# 852         0       3  female  9.00      1      1  15.2458        C   Third
# 869         1       3    male  4.00      1      1  11.1333        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[[[titanic['age'] < 10] & titanic['sex'] == 'female']]
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
# ----> 1 titanic[[[titanic['age'] < 10], titanic['sex'] == 'female']]
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
# ...

# %%
titanic[(titanic.age < 10) & (titanic.sex == 'female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 24          0       3  female  8.00      3      1   21.0750        S   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 58          1       2  female  5.00      1      2   27.7500        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 147         0       3  female  9.00      2      2   34.3750        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 184         1       3  female  4.00      0      2   22.0250        S   Third
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 233         1       3  female  5.00      4      2   31.3875        S   Third
# 237         1       2  female  8.00      0      2   26.2500        S  Second
# ...

# %%
titanic[(titanic['age'] < 10) & (titanic['sex'] == 'female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 24          0       3  female  8.00      3      1   21.0750        S   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 58          1       2  female  5.00      1      2   27.7500        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 147         0       3  female  9.00      2      2   34.3750        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 184         1       3  female  4.00      0      2   22.0250        S   Third
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 233         1       3  female  5.00      4      2   31.3875        S   Third
# 237         1       2  female  8.00      0      2   26.2500        S  Second
# ...

# %%
titanic.loc[(titanic.age<10) | (titanic.age >= 60), ['age', 'sex', 'alone']]
# Out:
#        age     sex  alone
# 7     2.00    male  False
# 10    4.00  female  False
# 16    2.00    male  False
# 24    8.00  female  False
# 33   66.00    male   True
# ..     ...     ...    ...
# 831   0.83    male  False
# 850   4.00    male  False
# 851  74.00    male   True
# 852   9.00  female  False
# 869   4.00    male  False
#
# [88 rows x 3 columns]

# %%
# filtering

titanic[titanic.age < 10]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male  2.00      3      1  21.0750        S   Third
# 10          1       3  female  4.00      1      1  16.7000        S   Third
# 16          0       3    male  2.00      4      1  29.1250        Q   Third
# 24          0       3  female  8.00      3      1  21.0750        S   Third
# 43          1       2  female  3.00      1      2  41.5792        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 827         1       2    male  1.00      0      2  37.0042        C  Second
# 831         1       2    male  0.83      1      1  18.7500        S  Second
# 850         0       3    male  4.00      4      2  31.2750        S   Third
# 852         0       3  female  9.00      1      1  15.2458        C   Third
# 869         1       3    male  4.00      1      1  11.1333        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.loc[(titanic.age < 10) & (titanic.sex == 'female'), :]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 24          0       3  female  8.00      3      1   21.0750        S   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 58          1       2  female  5.00      1      2   27.7500        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 147         0       3  female  9.00      2      2   34.3750        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 184         1       3  female  4.00      0      2   22.0250        S   Third
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 233         1       3  female  5.00      4      2   31.3875        S   Third
# 237         1       2  female  8.00      0      2   26.2500        S  Second
# ...

# %%
titanic.loc[(titanic.age < 10) | (titanic.age >= 60), ['age', 'sex', 'alone']]
# Out:
#        age     sex  alone
# 7     2.00    male  False
# 10    4.00  female  False
# 16    2.00    male  False
# 24    8.00  female  False
# 33   66.00    male   True
# ..     ...     ...    ...
# 831   0.83    male  False
# 850   4.00    male  False
# 851  74.00    male   True
# 852   9.00  female  False
# 869   4.00    male  False
#
# [88 rows x 3 columns]

# %%
pd.set_option('display.max_rows', 88) # 데이터프레임을 중간 생략 없이 다 보여줌, 행의 갯수보다 무조건 높게 숫자를 잡아야 다 보여줌
# 하나라도 적게 잡으면 중간 생략해서 나옴

# %%
titanic.loc[(titanic.age < 10) | (titanic.age >= 60), ['age', 'sex', 'alone']]
# Out:
#        age     sex  alone
# 7     2.00    male  False
# 10    4.00  female  False
# 16    2.00    male  False
# 24    8.00  female  False
# 33   66.00    male   True
# 43    3.00  female  False
# 50    7.00    male  False
# 54   65.00    male  False
# 58    5.00  female  False
# 63    4.00    male  False
# 78    0.83    male  False
# 96   71.00    male   True
# 116  70.50    male   True
# 119   2.00  female  False
# 147   9.00  female  False
# 164   1.00    male  False
# 165   9.00    male  False
# 170  61.00    male   True
# 171   4.00    male  False
# 172   1.00  female  False
# 182   9.00    male  False
# 183   1.00    male  False
# 184   4.00  female  False
# 193   3.00    male  False
# 205   2.00  female  False
# 233   5.00  female  False
# 237   8.00  female  False
# 252  62.00    male   True
# 261   3.00    male  False
# 275  63.00  female  False
# 278   7.00    male  False
# 280  65.00    male   True
# 297   2.00  female  False
# 305   0.92    male  False
# ...

# %%
pd.set_option('display.max_rows', 87)
titanic.loc[(titanic.age < 10) | (titanic.age >= 60), ['age', 'sex', 'alone']]
# Out:
#        age     sex  alone
# 7     2.00    male  False
# 10    4.00  female  False
# 16    2.00    male  False
# 24    8.00  female  False
# 33   66.00    male   True
# ..     ...     ...    ...
# 831   0.83    male  False
# 850   4.00    male  False
# 851  74.00    male   True
# 852   9.00  female  False
# 869   4.00    male  False
#
# [88 rows x 3 columns]

# %%
(titanic.sibsp == 3) | (titanic.sibsp == 4) | (titanic.sibsp == 5)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: sibsp, Length: 891, dtype: bool

# %%
titanic[(titanic.sibsp == 3) | (titanic.sibsp == 4) | (titanic.sibsp == 5)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 24          0       3  female   8.0      3      1   21.0750        S   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 50          0       3    male   7.0      4      1   39.6875        S   Third
# 59          0       3    male  11.0      5      2   46.9000        S   Third
# 63          0       3    male   4.0      3      2   27.9000        S   Third
# 68          1       3  female  17.0      4      2    7.9250        S   Third
# 71          0       3  female  16.0      5      2   46.9000        S   Third
# 85          1       3  female  33.0      3      0   15.8500        S   Third
# 88          1       1  female  23.0      3      2  263.0000        S   First
# ...

# %%
mask3 = titanic['sibsp'] == 3
mask4 = titanic['sibsp'] == 4
mask5 = titanic['sibsp'] == 5

# %%
titanic[mask3|mask4|mask5]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 24          0       3  female   8.0      3      1   21.0750        S   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 50          0       3    male   7.0      4      1   39.6875        S   Third
# 59          0       3    male  11.0      5      2   46.9000        S   Third
# 63          0       3    male   4.0      3      2   27.9000        S   Third
# 68          1       3  female  17.0      4      2    7.9250        S   Third
# 71          0       3  female  16.0      5      2   46.9000        S   Third
# 85          1       3  female  33.0      3      0   15.8500        S   Third
# 88          1       1  female  23.0      3      2  263.0000        S   First
# ...

# %%
titanic.sibsp.isin([3,4,5])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: sibsp, Length: 891, dtype: bool

# %%
titanic[titanic.sibsp.isin([3,4,5])]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 24          0       3  female   8.0      3      1   21.0750        S   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 50          0       3    male   7.0      4      1   39.6875        S   Third
# 59          0       3    male  11.0      5      2   46.9000        S   Third
# 63          0       3    male   4.0      3      2   27.9000        S   Third
# 68          1       3  female  17.0      4      2    7.9250        S   Third
# 71          0       3  female  16.0      5      2   46.9000        S   Third
# 85          1       3  female  33.0      3      0   15.8500        S   Third
# 88          1       1  female  23.0      3      2  263.0000        S   First
# ...

# %%
df1 = pd.DataFrame({'a': ['a0', 'a1', 'a2', 'a3'],
'b': ['b0', 'b1', 'b2', 'b3'],
'c': ['c0', 'c1', 'c2', 'c3']},
index=[0, 1, 2, 3])
df2 = pd.DataFrame({'a': ['a2', 'a3', 'a4', 'a5'],
'b': ['b2', 'b3', 'b4', 'b5'],
'c': ['c2', 'c3', 'c4', 'c5'],
'd': ['d2', 'd3', 'd4', 'd5']},
index=[2, 3, 4, 5])

# %%
df1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df2
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5

# %%
pd.concat([df1, df2], axis=0,)
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 2  a2  b2  c2   d2
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5

# %%
pd.concat([df1, df2], axis=0, ignore_index=True)
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 4  a2  b2  c2   d2
# 5  a3  b3  c3   d3
# 6  a4  b4  c4   d4
# 7  a5  b5  c5   d5

# %%
pd.concat([df1, df2], axis=1)
# Out:
#      a    b    c    a    b    c    d
# 0   a0   b0   c0  NaN  NaN  NaN  NaN
# 1   a1   b1   c1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   a2   b2   c2   d2
# 3   a3   b3   c3   a3   b3   c3   d3
# 4  NaN  NaN  NaN   a4   b4   c4   d4
# 5  NaN  NaN  NaN   a5   b5   c5   d5

# %%
pd.concat([df1, df2], axis=1, ignore_index=True, join = 'inner')
# Out:
#     0   1   2   3   4   5   6
# 2  a2  b2  c2  a2  b2  c2  d2
# 3  a3  b3  c3  a3  b3  c3  d3

# %%
sr1 = pd.Series(['e0', 'e1', 'e2', 'e3'], name='e')
sr2 = pd.Series(['f0', 'f1', 'f2'], name='f', index=[3, 4, 5])
sr3 = pd.Series(['g0', 'g1', 'g2', 'g3'], name='g')

# %%
pd.concat([df1, sr1], axis = 1)
# Out:
#     a   b   c   e
# 0  a0  b0  c0  e0
# 1  a1  b1  c1  e1
# 2  a2  b2  c2  e2
# 3  a3  b3  c3  e3

# %%
pd.concat([df2, sr2], axis=1)
# Out:
#     a   b   c   d    f
# 2  a2  b2  c2  d2  NaN
# 3  a3  b3  c3  d3   f0
# 4  a4  b4  c4  d4   f1
# 5  a5  b5  c5  d5   f2

# %%
pd.concat([df2, sr2], axis=1, sort=True)
# Out:
#     a   b   c   d    f
# 2  a2  b2  c2  d2  NaN
# 3  a3  b3  c3  d3   f0
# 4  a4  b4  c4  d4   f1
# 5  a5  b5  c5  d5   f2

# %%
pd.concat([sr1, sr3], axis = 1)
# Out:
#     e   g
# 0  e0  g0
# 1  e1  g1
# 2  e2  g2
# 3  e3  g3

# %%
pd.concat([sr1, sr3], axis = 0)
# Out:
# 0    e0
# 1    e1
# 2    e2
# 3    e3
# 0    g0
# 1    g1
# 2    g2
# 3    g3
# dtype: object

# %%
df1 = pd.read_excel('./stock price.xlsx')
df2 = pd.read_excel('./stock valuation.xlsx')

# %%
df1
# Out:
#        id stock_name          value   price
# 0  128940       한미약품   59385.666667  421000
# 1  130960     CJ E&M   58540.666667   98900
# 2  138250      엔에스쇼핑   14558.666667   13200
# 3  139480        이마트  239230.833333  254500
# 4  142280     녹십자엠에스     468.833333   10200
# 5  145990        삼양사   82750.000000   82000
# 6  185750        종근당   40293.666667  100500
# 7  192400      쿠쿠홀딩스  179204.666667  177500
# 8  199800         툴젠   -2514.333333  115400
# 9  204210     모두투어리츠    3093.333333    3475

# %%
df2
# Out:
#        id       name           eps     bps        per       pbr
# 0  130960     CJ E&M   6301.333333   54068  15.695091  1.829178
# 1  136480         하림    274.166667    3551  11.489362  0.887074
# 2  138040    메리츠금융지주   2122.333333   14894   6.313806  0.899691
# 3  139480        이마트  18268.166667  295780  13.931338  0.860437
# 4  145990        삼양사   5741.000000  108090  14.283226  0.758627
# 5  161390      한국타이어   5648.500000   51341   7.453306  0.820007
# 6  181710  NHN엔터테인먼트   2110.166667   78434  30.755864  0.827447
# 7  185750        종근당   3990.333333   40684  25.185866  2.470259
# 8  204210     모두투어리츠     85.166667    5335  40.802348  0.651359
# 9  207940   삼성바이오로직스   4644.166667   60099  89.790059  6.938551

# %%
pd.merge(left= df1, right=df2)
# Out:
#        id stock_name          value   price    name           eps     bps  \
# 0  130960     CJ E&M   58540.666667   98900  CJ E&M   6301.333333   54068
# 1  139480        이마트  239230.833333  254500     이마트  18268.166667  295780
# 2  145990        삼양사   82750.000000   82000     삼양사   5741.000000  108090
# 3  185750        종근당   40293.666667  100500     종근당   3990.333333   40684
# 4  204210     모두투어리츠    3093.333333    3475  모두투어리츠     85.166667    5335
#
#          per       pbr
# 0  15.695091  1.829178
# 1  13.931338  0.860437
# 2  14.283226  0.758627
# 3  25.185866  2.470259
# 4  40.802348  0.651359

# %%
pd.merge(left= df1, right=df2, how='outer', on=None)
# Out:
#         id stock_name          value     price       name           eps  \
# 0   128940       한미약품   59385.666667  421000.0        NaN           NaN
# 1   130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 2   138250      엔에스쇼핑   14558.666667   13200.0        NaN           NaN
# 3   139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 4   142280     녹십자엠에스     468.833333   10200.0        NaN           NaN
# 5   145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 6   185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 7   192400      쿠쿠홀딩스  179204.666667  177500.0        NaN           NaN
# 8   199800         툴젠   -2514.333333  115400.0        NaN           NaN
# 9   204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 10  136480        NaN            NaN       NaN         하림    274.166667
# 11  138040        NaN            NaN       NaN    메리츠금융지주   2122.333333
# ...

# %%
pd.merge(left= df1, right=df2, how='outer')
# Out:
#         id stock_name          value     price       name           eps  \
# 0   128940       한미약품   59385.666667  421000.0        NaN           NaN
# 1   130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 2   138250      엔에스쇼핑   14558.666667   13200.0        NaN           NaN
# 3   139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 4   142280     녹십자엠에스     468.833333   10200.0        NaN           NaN
# 5   145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 6   185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 7   192400      쿠쿠홀딩스  179204.666667  177500.0        NaN           NaN
# 8   199800         툴젠   -2514.333333  115400.0        NaN           NaN
# 9   204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 10  136480        NaN            NaN       NaN         하림    274.166667
# 11  138040        NaN            NaN       NaN    메리츠금융지주   2122.333333
# ...

# %%
pd.merge(df1, df2, how='left', left_on='stock_name', right_on='name')
# Out:
#      id_x stock_name          value   price      id_y    name           eps  \
# 0  128940       한미약품   59385.666667  421000       NaN     NaN           NaN
# 1  130960     CJ E&M   58540.666667   98900  130960.0  CJ E&M   6301.333333
# 2  138250      엔에스쇼핑   14558.666667   13200       NaN     NaN           NaN
# 3  139480        이마트  239230.833333  254500  139480.0     이마트  18268.166667
# 4  142280     녹십자엠에스     468.833333   10200       NaN     NaN           NaN
# 5  145990        삼양사   82750.000000   82000  145990.0     삼양사   5741.000000
# 6  185750        종근당   40293.666667  100500  185750.0     종근당   3990.333333
# 7  192400      쿠쿠홀딩스  179204.666667  177500       NaN     NaN           NaN
# 8  199800         툴젠   -2514.333333  115400       NaN     NaN           NaN
# 9  204210     모두투어리츠    3093.333333    3475  204210.0  모두투어리츠     85.166667
#
#         bps        per       pbr
# 0       NaN        NaN       NaN
# 1   54068.0  15.695091  1.829178
# ...

# %%
pd.merge(df1, df2, how='right', left_on='stock_name', right_on='name')
# Out:
#        id_x stock_name          value     price    id_y       name  \
# 0  130960.0     CJ E&M   58540.666667   98900.0  130960     CJ E&M
# 1       NaN        NaN            NaN       NaN  136480         하림
# 2       NaN        NaN            NaN       NaN  138040    메리츠금융지주
# 3  139480.0        이마트  239230.833333  254500.0  139480        이마트
# 4  145990.0        삼양사   82750.000000   82000.0  145990        삼양사
# 5       NaN        NaN            NaN       NaN  161390      한국타이어
# 6       NaN        NaN            NaN       NaN  181710  NHN엔터테인먼트
# 7  185750.0        종근당   40293.666667  100500.0  185750        종근당
# 8  204210.0     모두투어리츠    3093.333333    3475.0  204210     모두투어리츠
# 9       NaN        NaN            NaN       NaN  207940   삼성바이오로직스
#
#             eps     bps        per       pbr
# 0   6301.333333   54068  15.695091  1.829178
# 1    274.166667    3551  11.489362  0.887074
# 2   2122.333333   14894   6.313806  0.899691
# 3  18268.166667  295780  13.931338  0.860437
# ...

# %%
pd.merge(df2, df1, how='left', left_on='name', right_on='stock_name')
# Out:
#      id_x       name           eps     bps        per       pbr      id_y  \
# 0  130960     CJ E&M   6301.333333   54068  15.695091  1.829178  130960.0
# 1  136480         하림    274.166667    3551  11.489362  0.887074       NaN
# 2  138040    메리츠금융지주   2122.333333   14894   6.313806  0.899691       NaN
# 3  139480        이마트  18268.166667  295780  13.931338  0.860437  139480.0
# 4  145990        삼양사   5741.000000  108090  14.283226  0.758627  145990.0
# 5  161390      한국타이어   5648.500000   51341   7.453306  0.820007       NaN
# 6  181710  NHN엔터테인먼트   2110.166667   78434  30.755864  0.827447       NaN
# 7  185750        종근당   3990.333333   40684  25.185866  2.470259  185750.0
# 8  204210     모두투어리츠     85.166667    5335  40.802348  0.651359  204210.0
# 9  207940   삼성바이오로직스   4644.166667   60099  89.790059  6.938551       NaN
#
#   stock_name          value     price
# 0     CJ E&M   58540.666667   98900.0
# 1        NaN            NaN       NaN
# ...

# %%
df1[df1.price < 50000]
# Out:
#        id stock_name         value  price
# 2  138250      엔에스쇼핑  14558.666667  13200
# 4  142280     녹십자엠에스    468.833333  10200
# 9  204210     모두투어리츠   3093.333333   3475

# %%
pd.merge(df1[df1.price < 50000], df2)
# Out:
#        id stock_name        value  price    name        eps   bps        per  \
# 0  204210     모두투어리츠  3093.333333   3475  모두투어리츠  85.166667  5335  40.802348
#
#         pbr
# 0  0.651359

# %%
df1[].join(other = df2['eps'], how = 'left')
# Out:
#        id stock_name          value   price           eps
# 0  128940       한미약품   59385.666667  421000   6301.333333
# 1  130960     CJ E&M   58540.666667   98900    274.166667
# 2  138250      엔에스쇼핑   14558.666667   13200   2122.333333
# 3  139480        이마트  239230.833333  254500  18268.166667
# 4  142280     녹십자엠에스     468.833333   10200   5741.000000
# 5  145990        삼양사   82750.000000   82000   5648.500000
# 6  185750        종근당   40293.666667  100500   2110.166667
# 7  192400      쿠쿠홀딩스  179204.666667  177500   3990.333333
# 8  199800         툴젠   -2514.333333  115400     85.166667
# 9  204210     모두투어리츠    3093.333333    3475   4644.166667

# %%
df2.join(other = df1['price'], how = 'left')
# Out:
#        id       name           eps     bps        per       pbr   price
# 0  130960     CJ E&M   6301.333333   54068  15.695091  1.829178  421000
# 1  136480         하림    274.166667    3551  11.489362  0.887074   98900
# 2  138040    메리츠금융지주   2122.333333   14894   6.313806  0.899691   13200
# 3  139480        이마트  18268.166667  295780  13.931338  0.860437  254500
# 4  145990        삼양사   5741.000000  108090  14.283226  0.758627   10200
# 5  161390      한국타이어   5648.500000   51341   7.453306  0.820007   82000
# 6  181710  NHN엔터테인먼트   2110.166667   78434  30.755864  0.827447  100500
# 7  185750        종근당   3990.333333   40684  25.185866  2.470259  177500
# 8  204210     모두투어리츠     85.166667    5335  40.802348  0.651359  115400
# 9  207940   삼성바이오로직스   4644.166667   60099  89.790059  6.938551    3475

# %%
df1[df1.price < 5000].joinn(df2, how='inner', on = 'id')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [223], in <cell line: 1>()
# ----> 1 df1[df1.price < 5000].joinn(df2, how='inner', on = 'id')
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'joinn'

# %%
df1.set_index('id', inplace=True)
df2.set_index('id', inplace=True)
#이미 셋인덱스로 해놔서 다시 하려니 오류 난거임
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [227], in <cell line: 1>()
# ----> 1 df1.set_index('id', inplace=True)
#       2 df2.set_index('id', inplace=True)
#       3 df1
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# ...

# %%
df1
# Out:
#        stock_name          value   price
# id
# 128940       한미약품   59385.666667  421000
# 130960     CJ E&M   58540.666667   98900
# 138250      엔에스쇼핑   14558.666667   13200
# 139480        이마트  239230.833333  254500
# 142280     녹십자엠에스     468.833333   10200
# 145990        삼양사   82750.000000   82000
# 185750        종근당   40293.666667  100500
# 192400      쿠쿠홀딩스  179204.666667  177500
# 199800         툴젠   -2514.333333  115400
# 204210     모두투어리츠    3093.333333    3475

# %%
df2
# Out:
#              name           eps     bps        per       pbr
# id
# 130960     CJ E&M   6301.333333   54068  15.695091  1.829178
# 136480         하림    274.166667    3551  11.489362  0.887074
# 138040    메리츠금융지주   2122.333333   14894   6.313806  0.899691
# 139480        이마트  18268.166667  295780  13.931338  0.860437
# 145990        삼양사   5741.000000  108090  14.283226  0.758627
# 161390      한국타이어   5648.500000   51341   7.453306  0.820007
# 181710  NHN엔터테인먼트   2110.166667   78434  30.755864  0.827447
# 185750        종근당   3990.333333   40684  25.185866  2.470259
# 204210     모두투어리츠     85.166667    5335  40.802348  0.651359
# 207940   삼성바이오로직스   4644.166667   60099  89.790059  6.938551

# %%
df1.join(df2, how='left')
# Out:
#        stock_name          value   price    name           eps       bps  \
# id
# 128940       한미약품   59385.666667  421000     NaN           NaN       NaN
# 130960     CJ E&M   58540.666667   98900  CJ E&M   6301.333333   54068.0
# 138250      엔에스쇼핑   14558.666667   13200     NaN           NaN       NaN
# 139480        이마트  239230.833333  254500     이마트  18268.166667  295780.0
# 142280     녹십자엠에스     468.833333   10200     NaN           NaN       NaN
# 145990        삼양사   82750.000000   82000     삼양사   5741.000000  108090.0
# 185750        종근당   40293.666667  100500     종근당   3990.333333   40684.0
# 192400      쿠쿠홀딩스  179204.666667  177500     NaN           NaN       NaN
# 199800         툴젠   -2514.333333  115400     NaN           NaN       NaN
# 204210     모두투어리츠    3093.333333    3475  모두투어리츠     85.166667    5335.0
#
#               per       pbr
# id
# 128940        NaN       NaN
# 130960  15.695091  1.829178
# 138250        NaN       NaN
# 139480  13.931338  0.860437
# ...

# %%
df1.join(df2, how = 'inner')
# Out:
#        stock_name          value   price    name           eps     bps  \
# id
# 130960     CJ E&M   58540.666667   98900  CJ E&M   6301.333333   54068
# 139480        이마트  239230.833333  254500     이마트  18268.166667  295780
# 145990        삼양사   82750.000000   82000     삼양사   5741.000000  108090
# 185750        종근당   40293.666667  100500     종근당   3990.333333   40684
# 204210     모두투어리츠    3093.333333    3475  모두투어리츠     85.166667    5335
#
#               per       pbr
# id
# 130960  15.695091  1.829178
# 139480  13.931338  0.860437
# 145990  14.283226  0.758627
# 185750  25.185866  2.470259
# 204210  40.802348  0.651359

# %%
df = titanic.loc[:,['age', 'sex', 'class', 'fare', 'survived']]

# %%
df
# Out:
#       age     sex   class     fare  survived
# 0    22.0    male   Third   7.2500         0
# 1    38.0  female   First  71.2833         1
# 2    26.0  female   Third   7.9250         1
# 3    35.0  female   First  53.1000         1
# 4    35.0    male   Third   8.0500         0
# ..    ...     ...     ...      ...       ...
# 886  27.0    male  Second  13.0000         0
# 887  19.0  female   First  30.0000         1
# 888   NaN  female   Third  23.4500         0
# 889  26.0    male   First  30.0000         1
# 890  32.0    male   Third   7.7500         0
#
# [891 rows x 5 columns]

# %%
grouped = df.groupby(['class'])

# %%
grouped

# %%
len(grouped)
# Out:
# 3

# %%
df['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
grouped.head(5)
# Out:
#      age     sex   class     fare  survived
# 0   22.0    male   Third   7.2500         0
# 1   38.0  female   First  71.2833         1
# 2   26.0  female   Third   7.9250         1
# 3   35.0  female   First  53.1000         1
# 4   35.0    male   Third   8.0500         0
# 5    NaN    male   Third   8.4583         0
# 6   54.0    male   First  51.8625         0
# 7    2.0    male   Third  21.0750         0
# 9   14.0  female  Second  30.0708         1
# 11  58.0  female   First  26.5500         1
# 15  55.0  female  Second  16.0000         1
# 17   NaN    male  Second  13.0000         1
# 20  35.0    male  Second  26.0000         0
# 21  34.0    male  Second  13.0000         1
# 23  28.0    male   First  35.5000         1

# %%
for i in range(6):
    print(grouped.head(i))
# Out:
# Empty DataFrame
# Columns: [age, sex, class, fare, survived]
# Index: []
#     age     sex   class     fare  survived
# 0  22.0    male   Third   7.2500         0
# 1  38.0  female   First  71.2833         1
# 9  14.0  female  Second  30.0708         1
#      age     sex   class     fare  survived
# 0   22.0    male   Third   7.2500         0
# 1   38.0  female   First  71.2833         1
# 2   26.0  female   Third   7.9250         1
# 3   35.0  female   First  53.1000         1
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
#      age     sex   class     fare  survived
# 0   22.0    male   Third   7.2500         0
# 1   38.0  female   First  71.2833         1
# 2   26.0  female   Third   7.9250         1
# 3   35.0  female   First  53.1000         1
# 4   35.0    male   Third   8.0500         0
# 6   54.0    male   First  51.8625         0
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# ...

# %%
a = 0
for i in range(5): 
    a+=1
    print(a)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for key, group in grouped:
    print(key)
    print(group.head(3))
# Out:
# First
#     age     sex  class     fare  survived
# 1  38.0  female  First  71.2833         1
# 3  35.0  female  First  53.1000         1
# 6  54.0    male  First  51.8625         0
# Second
#      age     sex   class     fare  survived
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# 17   NaN    male  Second  13.0000         1
# Third
#     age     sex  class   fare  survived
# 0  22.0    male  Third  7.250         0
# 2  26.0  female  Third  7.925         1
# 4  35.0    male  Third  8.050         0

# %%
grouped.mean()
# Out:
#               age       fare  survived
# class
# First   38.233441  84.154687  0.629630
# Second  29.877630  20.662183  0.472826
# Third   25.140620  13.675550  0.242363

# %%
grouped.mean()['age']
# Out:
# class
# First     38.233441
# Second    29.877630
# Third     25.140620
# Name: age, dtype: float64

# %%
df.groupby('class').mean()
# Out:
#               age       fare  survived
# class
# First   38.233441  84.154687  0.629630
# Second  29.877630  20.662183  0.472826
# Third   25.140620  13.675550  0.242363

# %%
df.groupby('class').get_group('Third')
# Out:
#       age     sex  class     fare  survived
# 0    22.0    male  Third   7.2500         0
# 2    26.0  female  Third   7.9250         1
# 4    35.0    male  Third   8.0500         0
# 5     NaN    male  Third   8.4583         0
# 7     2.0    male  Third  21.0750         0
# ..    ...     ...    ...      ...       ...
# 882  22.0  female  Third  10.5167         0
# 884  25.0    male  Third   7.0500         0
# 885  39.0  female  Third  29.1250         0
# 888   NaN  female  Third  23.4500         0
# 890  32.0    male  Third   7.7500         0
#
# [491 rows x 5 columns]

# %%
df[df['class'] == 'Third']
# Out:
#       age     sex  class     fare  survived
# 0    22.0    male  Third   7.2500         0
# 2    26.0  female  Third   7.9250         1
# 4    35.0    male  Third   8.0500         0
# 5     NaN    male  Third   8.4583         0
# 7     2.0    male  Third  21.0750         0
# ..    ...     ...    ...      ...       ...
# 882  22.0  female  Third  10.5167         0
# 884  25.0    male  Third   7.0500         0
# 885  39.0  female  Third  29.1250         0
# 888   NaN  female  Third  23.4500         0
# 890  32.0    male  Third   7.7500         0
#
# [491 rows x 5 columns]

# %%
grouped_2 = df.groupby(['class','sex'])

# %%
df.groupby(['class','sex']).mean()
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447

# %%
df.groupby(['class','sex']).get_group(('Third', 'female'))
# Out:
#       age     sex  class     fare  survived
# 2    26.0  female  Third   7.9250         1
# 8    27.0  female  Third  11.1333         1
# 10    4.0  female  Third  16.7000         1
# 14   14.0  female  Third   7.8542         0
# 18   31.0  female  Third  18.0000         0
# ..    ...     ...    ...      ...       ...
# 863   NaN  female  Third  69.5500         0
# 875  15.0  female  Third   7.2250         1
# 882  22.0  female  Third  10.5167         0
# 885  39.0  female  Third  29.1250         0
# 888   NaN  female  Third  23.4500         0
#
# [144 rows x 5 columns]

# %%
grouped_2.max()
# Out:
#                 age      fare  survived
# class  sex
# First  female  63.0  512.3292         1
#        male    80.0  512.3292         1
# Second female  57.0   65.0000         1
#        male    70.0   73.5000         1
# Third  female  63.0   69.5500         1
#        male    74.0   69.5500         1

# %%
grouped_2.mean()
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447

# %%
grouped_2.min()
# Out:
#                 age     fare  survived
# class  sex
# First  female  2.00  25.9292         0
#        male    0.92   0.0000         0
# Second female  2.00  10.5000         0
#        male    0.67   0.0000         0
# Third  female  0.75   6.7500         0
#        male    0.42   0.0000         0

# %%
for key, group in df.groupby('class', 'sex'):
    print(key)
    print(group)
# Out:
# First
# 1      female
# 3      female
# 6        male
# 11     female
# 23       male
#         ...
# 871    female
# 872      male
# 879    female
# 887    female
# 889      male
# Name: sex, Length: 216, dtype: object
# Second
# 9      female
# 15     female
# 17       male
# 20       male
# 21       male
#         ...
# 866    female
# 874    female
# 880    female
# 883      male
# 886      male
# Name: sex, Length: 184, dtype: object
# Third
# 0        male
# 2      female
# 4        male
# 5        male
# 7        male
#         ...
# 882    female
# 884      male
# 885    female
# 888    female
# 890      male
# Name: sex, Length: 491, dtype: object

# %%
grouped_2.sum()
# Out:
#                    age       fare  survived
# class  sex
# First  female  2942.00  9975.8250        91
#        male    4169.42  8201.5875        45
# Second female  2125.50  1669.7292        70
#        male    3043.33  2132.1125        17
# Third  female  2218.50  2321.1086        72
#        male    6706.42  4393.5865        47

# %%
grouped_2.count()
# Out:
#                age  fare  survived
# class  sex
# First  female   85    94        94
#        male    101   122       122
# Second female   74    76        76
#        male     99   108       108
# Third  female  102   144       144
#        male    253   347       347

# %%
grouped.std()
# Out:
#               age       fare  survived
# class
# First   14.802856  78.380373  0.484026
# Second  14.001077  13.417399  0.500623
# Third   12.495398  11.778142  0.428949

# %%
grouped.count()
# Out:
#         age  sex  fare  survived
# class
# First   186  216   216       216
# Second  173  184   184       184
# Third   355  491   491       491

# %%
grouped.size()
# Out:
# class
# First     216
# Second    184
# Third     491
# dtype: int64

# %%
grouped.describe()
# Out:
#           age                                                       fare  \
#         count       mean        std   min   25%   50%   75%   max  count
# class
# First   186.0  38.233441  14.802856  0.92  27.0  37.0  49.0  80.0  216.0
# Second  173.0  29.877630  14.001077  0.67  23.0  29.0  36.0  70.0  184.0
# Third   355.0  25.140620  12.495398  0.42  18.0  24.0  32.0  74.0  491.0
#
#                    ...                 survived                                \
#              mean  ...   75%       max    count      mean       std  min  25%
# class              ...
# First   84.154687  ...  93.5  512.3292    216.0  0.629630  0.484026  0.0  0.0
# Second  20.662183  ...  26.0   73.5000    184.0  0.472826  0.500623  0.0  0.0
# Third   13.675550  ...  15.5   69.5500    491.0  0.242363  0.428949  0.0  0.0
#
#
#         50%  75%  max
# class
# First   1.0  1.0  1.0
# Second  0.0  1.0  1.0
# Third   0.0  0.0  1.0
#
# [3 rows x 24 columns]

# %%
grouped.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [290], in <cell line: 1>()
# ----> 1 grouped.info()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'info'

# %%
grouped.fare

# %%
grouped.fare.head(5)
# Out:
# 0      7.2500
# 1     71.2833
# 2      7.9250
# 3     53.1000
# 4      8.0500
# 5      8.4583
# 6     51.8625
# 7     21.0750
# 9     30.0708
# 11    26.5500
# 15    16.0000
# 17    13.0000
# 20    26.0000
# 21    13.0000
# 23    35.5000
# Name: fare, dtype: float64

# %%
grouped.fare.std()
# Out:
# class
# First     78.380373
# Second    13.417399
# Third     11.778142
# Name: fare, dtype: float64

# %%
def min_max(a):
    return a.min(), a.max()
grouped.agg(min_max)
# Out:
#                  age             sex             fare survived
# class
# First   (0.92, 80.0)  (female, male)  (0.0, 512.3292)   (0, 1)
# Second  (0.67, 70.0)  (female, male)      (0.0, 73.5)   (0, 1)
# Third   (0.42, 74.0)  (female, male)     (0.0, 69.55)   (0, 1)

# %%
def min__max(a):
    return  a.max() - a.min()
grouped.agg(min__max)
# Out:
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/3791424228.py:3: FutureWarning: ['sex'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   grouped.agg(min__max)
#           age      fare  survived
# class
# First   79.08  512.3292         1
# Second  69.33   73.5000         1
# Third   73.58   69.5500         1

# %%
grouped.agg([min_max, mean])
# Out:
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/2831346894.py:1: FutureWarning: ['sex'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   grouped.agg([min_max, mean])
#                  age                        fare            survived
#              min_max       mean          min_max       mean  min_max      mean
# class
# First   (0.92, 80.0)  38.233441  (0.0, 512.3292)  84.154687   (0, 1)  0.629630
# Second  (0.67, 70.0)  29.877630      (0.0, 73.5)  20.662183   (0, 1)  0.472826
# Third   (0.42, 74.0)  25.140620     (0.0, 69.55)  13.675550   (0, 1)  0.242363

# %%
def mean(a):
    return a.mean()
grouped.agg({'fare' : min_max, 'age' : mean})
# Out:
#                    fare        age
# class
# First   (0.0, 512.3292)  38.233441
# Second      (0.0, 73.5)  29.877630
# Third      (0.0, 69.55)  25.140620

# %%
grouped.age.head(3)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 6     54.0
# 9     14.0
# 15    55.0
# 17     NaN
# Name: age, dtype: float64

# %%
def z_score(x):
    return (x-x.mean())/x.std()

# %%
grouped.age.transform(z_score)
# Out:
# 0     -0.251342
# 1     -0.015770
# 2      0.068776
# 3     -0.218434
# 4      0.789041
#          ...
# 886   -0.205529
# 887   -1.299306
# 888         NaN
# 889   -0.826424
# 890    0.548953
# Name: age, Length: 891, dtype: float64

# %%
grouped.agg(z_score)
# Out:
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/4291541429.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return (x-x.mean())/x.std()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:900, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     899 try:
# --> 900     result = gba.agg()
#     902 except ValueError as err:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:171, in Apply.agg(self)
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
# --> 171     return self.agg_list_like()
#     173 if callable(arg):
#
# ...

# %%
grouped.transform(min__max).age.unique()
# Out:
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/1987493614.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the function.
#   grouped.transform(min__max).age.unique()
# array([73.58, 79.08, 69.33])

# %%
grouped.age.agg(min__max)
# Out:
# class
# First     79.08
# Second    69.33
# Third     73.58
# Name: age, dtype: float64

# %%
grouped.age.transform(z_score)
# Out:
# 0     -0.251342
# 1     -0.015770
# 2      0.068776
# 3     -0.218434
# 4      0.789041
#          ...
# 886   -0.205529
# 887   -1.299306
# 888         NaN
# 889   -0.826424
# 890    0.548953
# Name: age, Length: 891, dtype: float64

# %%
grouped.transform(z_score)
# Out:
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/99382137.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the function.
#   grouped.transform(z_score)
#           age      fare  survived
# 0   -0.251342 -0.545549 -0.565014
# 1   -0.015770 -0.164217  0.765188
# 2    0.068776 -0.488239  1.766263
# 3   -0.218434 -0.396205  0.765188
# 4    0.789041 -0.477626 -0.565014
# ..        ...       ...       ...
# 886 -0.205529 -0.571063 -0.944475
# 887 -1.299306 -0.690922  0.765188
# 888       NaN  0.829880 -0.565014
# 889 -0.826424 -0.690922  0.765188
# 890  0.548953 -0.503097 -0.565014
#
# [891 rows x 3 columns]

# %%
def over200(a):
    
    return len(a) > 200

# %%
grouped.filter(lambda x: len(x) >= 200)
# Out:
#       age     sex  class     fare  survived
# 0    22.0    male  Third   7.2500         0
# 1    38.0  female  First  71.2833         1
# 2    26.0  female  Third   7.9250         1
# 3    35.0  female  First  53.1000         1
# 4    35.0    male  Third   8.0500         0
# ..    ...     ...    ...      ...       ...
# 885  39.0  female  Third  29.1250         0
# 887  19.0  female  First  30.0000         1
# 888   NaN  female  Third  23.4500         0
# 889  26.0    male  First  30.0000         1
# 890  32.0    male  Third   7.7500         0
#
# [707 rows x 5 columns]

# %%
grouped.get_group('First').shape
# Out:
# (216, 5)

# %%
grouped.get_group('Second').shape
# Out:
# (184, 5)

# %%
grouped.get_group('Third').shape
# Out:
# (491, 5)

# %%
grouped.filter(lambda x: x.age.mean() < 30)
# Out:
#       age     sex   class     fare  survived
# 0    22.0    male   Third   7.2500         0
# 2    26.0  female   Third   7.9250         1
# 4    35.0    male   Third   8.0500         0
# 5     NaN    male   Third   8.4583         0
# 7     2.0    male   Third  21.0750         0
# ..    ...     ...     ...      ...       ...
# 884  25.0    male   Third   7.0500         0
# 885  39.0  female   Third  29.1250         0
# 886  27.0    male  Second  13.0000         0
# 888   NaN  female   Third  23.4500         0
# 890  32.0    male   Third   7.7500         0
#
# [675 rows x 5 columns]

# %%
grouped.age.mean()
# Out:
# class
# First     38.233441
# Second    29.877630
# Third     25.140620
# Name: age, dtype: float64

# %%
def over30(a):
    return a >30

# %%
grouped.age.filter(over30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:524, in SeriesGroupBy.filter(self, func, dropna, *args, **kwargs)
#     523 try:
# --> 524     indices = [
#     525         self._get_index(name) for name, group in self if true_and_notna(group)
#     526     ]
#     527 except (ValueError, TypeError) as err:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:525, in <listcomp>(.0)
#     523 try:
#     524     indices = [
# --> 525         self._get_index(name) for name, group in self if true_and_notna(group)
#     526     ]
#     527 except (ValueError, TypeError) as err:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:521, in SeriesGroupBy.filter.<locals>.true_and_notna(x)
#     520 b = wrapper(x)
# --> 521 return b and notna(b)
#
# ...

# %%
grouped.apply(z_score)
# Out:
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/4291541429.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return (x-x.mean())/x.std()
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/4291541429.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return (x-x.mean())/x.std()
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/4291541429.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return (x-x.mean())/x.std()
# ...

# %%
grouped.apply(z_score)

# %%
df.describe()
# Out:
#               age        fare    survived
# count  714.000000  891.000000  891.000000
# mean    29.699118   32.204208    0.383838
# std     14.526497   49.693429    0.486592
# min      0.420000    0.000000    0.000000
# 25%     20.125000    7.910400    0.000000
# 50%     28.000000   14.454200    0.000000
# 75%     38.000000   31.000000    1.000000
# max     80.000000  512.329200    1.000000

# %%
df.age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
grouped.apply(lambda x: x.describe())
# Out:
#                      age        fare    survived
# class
# First  count  186.000000  216.000000  216.000000
#        mean    38.233441   84.154687    0.629630
#        std     14.802856   78.380373    0.484026
#        min      0.920000    0.000000    0.000000
#        25%     27.000000   30.923950    0.000000
#        50%     37.000000   60.287500    1.000000
#        75%     49.000000   93.500000    1.000000
#        max     80.000000  512.329200    1.000000
# Second count  173.000000  184.000000  184.000000
#        mean    29.877630   20.662183    0.472826
#        std     14.001077   13.417399    0.500623
#        min      0.670000    0.000000    0.000000
#        25%     23.000000   13.000000    0.000000
#        50%     29.000000   14.250000    0.000000
#        75%     36.000000   26.000000    1.000000
#        max     70.000000   73.500000    1.000000
# Third  count  355.000000  491.000000  491.000000
#        mean    25.140620   13.675550    0.242363
# ...

# %%
grouped.age.apply(z_score)
# Out:
# 0     -0.251342
# 1     -0.015770
# 2      0.068776
# 3     -0.218434
# 4      0.789041
#          ...
# 886   -0.205529
# 887   -1.299306
# 888         NaN
# 889   -0.826424
# 890    0.548953
# Name: age, Length: 891, dtype: float64

# %%
grouped.apply(z_score)
# Out:
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/4291541429.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return (x-x.mean())/x.std()
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/4291541429.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return (x-x.mean())/x.std()
# /var/folders/fl/lytw3yqx5913yh2tcxgw3d740000gn/T/ipykernel_1224/4291541429.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return (x-x.mean())/x.std()
# ...

# %%
age_ft = grouped.apply(lambda x: x.age.mean() < 30)

# %%
age_ft
# Out:
# class
# First     False
# Second     True
# Third      True
# dtype: bool

# %%
 for i in age_ft.index:
        print(i)
# Out:
# First
# Second
# Third

# %%
 for i in age_ft.index:
        if age_ft[i] == True:
            print(grouped.get_group(i))
# Out:
#       age     sex   class     fare  survived
# 9    14.0  female  Second  30.0708         1
# 15   55.0  female  Second  16.0000         1
# 17    NaN    male  Second  13.0000         1
# 20   35.0    male  Second  26.0000         0
# 21   34.0    male  Second  13.0000         1
# ..    ...     ...     ...      ...       ...
# 866  27.0  female  Second  13.8583         1
# 874  28.0  female  Second  24.0000         1
# 880  25.0  female  Second  26.0000         1
# 883  28.0    male  Second  10.5000         0
# 886  27.0    male  Second  13.0000         0
#
# [184 rows x 5 columns]
#       age     sex  class     fare  survived
# 0    22.0    male  Third   7.2500         0
# 2    26.0  female  Third   7.9250         1
# 4    35.0    male  Third   8.0500         0
# 5     NaN    male  Third   8.4583         0
# 7     2.0    male  Third  21.0750         0
# ..    ...     ...    ...      ...       ...
# 882  22.0  female  Third  10.5167         0
# ...

# %%
grouped.filter(lambda x: x.age.mean() < 30)
# Out:
#       age     sex   class     fare  survived
# 0    22.0    male   Third   7.2500         0
# 2    26.0  female   Third   7.9250         1
# 4    35.0    male   Third   8.0500         0
# 5     NaN    male   Third   8.4583         0
# 7     2.0    male   Third  21.0750         0
# ..    ...     ...     ...      ...       ...
# 884  25.0    male   Third   7.0500         0
# 885  39.0  female   Third  29.1250         0
# 886  27.0    male  Second  13.0000         0
# 888   NaN  female   Third  23.4500         0
# 890  32.0    male   Third   7.7500         0
#
# [675 rows x 5 columns]

# %%
grouped_2 = df.groupby(['class', 'sex'])

# %%
gdf = grouped_2.mean()

# %%
gdf
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447

# %%
type(gdf)
# Out:
# pandas.core.frame.DataFrame

# %%
gdf.loc['First']
# Out:
#               age        fare  survived
# sex
# female  34.611765  106.125798  0.968085
# male    41.281386   67.226127  0.368852

# %%
gdf.loc['First','female']
# Out:
# age          34.611765
# fare        106.125798
# survived      0.968085
# Name: (First, female), dtype: float64

# %%
gdf.loc[('First','female'), :]
# Out:
# age          34.611765
# fare        106.125798
# survived      0.968085
# Name: (First, female), dtype: float64

# %%
gdf.loc[(['First', 'Second', 'Third'], 'male'), :]
# Out:
#                    age       fare  survived
# class  sex
# First  male  41.281386  67.226127  0.368852
# Second male  30.740707  19.741782  0.157407
# Third  male  26.507589  12.661633  0.135447

# %%
gdf.xs('Third')
# Out:
#               age       fare  survived
# sex
# female  21.750000  16.118810  0.500000
# male    26.507589  12.661633  0.135447

# %%
gdf.xs('male', level='sex')
# Out:
#               age       fare  survived
# class
# First   41.281386  67.226127  0.368852
# Second  30.740707  19.741782  0.157407
# Third   26.507589  12.661633  0.135447

# %%
df
# Out:
#       age     sex   class     fare  survived
# 0    22.0    male   Third   7.2500         0
# 1    38.0  female   First  71.2833         1
# 2    26.0  female   Third   7.9250         1
# 3    35.0  female   First  53.1000         1
# 4    35.0    male   Third   8.0500         0
# ..    ...     ...     ...      ...       ...
# 886  27.0    male  Second  13.0000         0
# 887  19.0  female   First  30.0000         1
# 888   NaN  female   Third  23.4500         0
# 889  26.0    male   First  30.0000         1
# 890  32.0    male   Third   7.7500         0
#
# [891 rows x 5 columns]

# %%
df.pivot_table(index='class', columns='sex', values='age', aggfunc='mean')
# Out:
# sex        female       male
# class
# First   34.611765  41.281386
# Second  28.722973  30.740707
# Third   21.750000  26.507589

# %%
pd.pivot_table(df, values='age', index='class', columns='sex', aggfunc='mean')
# Out:
# sex        female       male
# class
# First   34.611765  41.281386
# Second  28.722973  30.740707
# Third   21.750000  26.507589

# %%
pd.pivot_table(df, values='survived', index='class', columns='sex', aggfunc=['mean', 'sum'])
# Out:
#             mean              sum
# sex       female      male female male
# class
# First   0.968085  0.368852     91   45
# Second  0.921053  0.157407     70   17
# Third   0.500000  0.135447     72   47

# %%
pd.pivot_table(df, values=['age','fare'], index=['class','sex'], columns='survived', aggfunc=['mean', 'max'])
# Out:
#                     mean                                      max        \
#                      age                   fare               age
# survived               0          1           0           1     0     1
# class  sex
# First  female  25.666667  34.939024  110.604167  105.978159  50.0  63.0
#        male    44.581967  36.248000   62.894910   74.637320  71.0  80.0
# Second female  36.000000  28.080882   18.250000   22.288989  57.0  55.0
#        male    33.369048  16.022000   19.488965   21.095100  70.0  62.0
# Third  female  23.818182  19.329787   19.773093   12.464526  48.0  63.0
#        male    27.255814  22.274211   12.204469   15.579696  74.0  45.0
#
#
#                  fare
# survived            0         1
# class  sex
# First  female  151.55  512.3292
#        male    263.00  512.3292
# Second female   26.00   65.0000
#        male     73.50   39.0000
# Third  female   69.55   31.3875
#        male     69.55   56.4958

# %%
pd.pivot_table(df, values=['age','fare'], 
               index=['class','sex'], 
               columns='survived', 
               aggfunc=['mean', 'max']).xs('male', level='sex')
# Out:
#                mean                                    max                \
#                 age                  fare              age          fare
# survived          0          1          0          1     0     1       0
# class
# First     44.581967  36.248000  62.894910  74.637320  71.0  80.0  263.00
# Second    33.369048  16.022000  19.488965  21.095100  70.0  62.0   73.50
# Third     27.255814  22.274211  12.204469  15.579696  74.0  45.0   69.55
#
#
#
# survived         1
# class
# First     512.3292
# Second     39.0000
# Third      56.4958
